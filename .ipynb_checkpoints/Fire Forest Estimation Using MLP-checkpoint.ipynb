# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
# %matplotlib inline

# %%
dataset = pd.read_csv('dataset/forestfires.csv')

# %%
dataset.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### Data Information

# %% [markdown]
# `X`      : x-axis spatial coordinate within the Montesinho park map: 1 to 9
# `Y`      : y-axis spatial coordinate within the Montesinho park map: 2 to 9
# `month`  : month of the year: "jan" to "dec"
# `day`    : day of the week: "mon" to "sun"
# `FFMC`   : FFMC index from the FWI system: 18.7 to 96.20
# `DMC`    : DMC index from the FWI system: 1.1 to 291.3
# `DC`     : DC index from the FWI system: 7.9 to 860.6
# `ISI`    : ISI index from the FWI system: 0.0 to 56.10
# `temp`   : temperature in Celsius degrees: 2.2 to 33.30
# `RH`     : relative humidity in %: 15.0 to 100
# `wind`   : wind speed in km/h: 0.40 to 9.40
# `rain`   : outside rain in mm/m2 : 0.0 to 6.4
# `area`   : the burned area of the forest (in ha): 0.00 to 1090.84

# %% [markdown]
# - `FFMC` (Fine Fuel Moisture Code) menunjukkan kadar air permukaan serasah (di bawah naungan kanopi hutan) berupa tumpukan dedaunan kering, rerantingan, dan berbagai sisa vegetasi lainnya yang mempengaruhi penyulutan dan penyebaran api.`FFMC` dipengaruhi oleh `rain`(hujan), `RH` (kelembapan relatif), `temp` (suhu), dan `wind` (angin).
#
# - `DMC` (Duff Moisture Code) mewakili kadar air lapisan organik tidak padat dibawah lapisan serasah bagian dangkal berupa materi berkayu berukuran sedang yang mengindikasikan konsumsi bahan bakar. `DMC` dipengaruhi oleh `rain`, `RH`, dan `temp`.
#
# - `DC` (Drought Code) mewakili kadar air lapisan organik padat dibawah lapisan dalam berupa materi kayu berukuran besar yang mempengaruhi intensitas kebakaran dan potensi kabut asap. `DC` dipengaruhi oleh `rain` dan `temp`.
#
# - `ISI` (Intitial Spread Index) adalah skor yang berkorelasi dengan penyebaran kecepatan api dengan menggabungkan `wind` dan `FFMC`, sedangkan `BUI` mewakili jumlah bahan bakar yang tersedia yang merupakan kombinasi dari `DMC` dan `DC`. Indeks FWI merupakan indikator intensitas kebakaran dan menggabungkan `ISI` dan `BUI`
#
# Source:
#
# https://media.neliti.com/media/publications/191646-ID-sistem-informasi-tingkat-bahaya-kebakara.pdf
#
# https://www.nwcg.gov/publications/pms437/cffdrs/fire-weather-index-system

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ### Check Missing Data

# %%
dataset.isnull().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %% [markdown]
# ### Check Duplicate Data

# %%
print("jumlah baris data:", dataset.shape[0])
print("jumlah data terduplikat:", dataset.duplicated().sum())
# Out:
# jumlah baris data: 517
# jumlah data terduplikat: 4

# %%
# Menghapus data duplikat
dataset.drop_duplicates(inplace=True)
print("jumlah baris data setelah penghapusan:", dataset.shape[0])
# Out:
# jumlah baris data setelah penghapusan: 513

# %% [markdown]
# ## Features Exploration

# %% [markdown]
# ### Deskriptif Statistik

# %%
# numerical descriptive statistic
dataset.describe().transpose()
# Out:
#       count        mean         std   min    25%     50%     75%      max
# X     513.0    4.678363    2.320059   1.0    3.0    4.00    7.00     9.00
# Y     513.0    4.300195    1.230925   2.0    4.0    4.00    5.00     9.00
# FFMC  513.0   90.637427    5.540920  18.7   90.2   91.60   92.90    96.20
# DMC   513.0  110.989279   64.191013   1.1   68.6  108.30  142.40   291.30
# DC    513.0  549.155166  247.724594   7.9  440.9  664.50  713.90   860.60
# ISI   513.0    9.023587    4.575543   0.0    6.4    8.40   11.00    56.10
# temp  513.0   18.887524    5.828128   2.2   15.5   19.30   22.80    33.30
# RH    513.0   44.348928   16.358803  15.0   33.0   42.00   53.00   100.00
# wind  513.0    4.010526    1.796613   0.4    2.7    4.00    4.90     9.40
# rain  513.0    0.021832    0.297107   0.0    0.0    0.00    0.00     6.40
# area  513.0   12.891598   63.892586   0.0    0.0    0.54    6.57  1090.84

# %%
# categorical descriptive statistic
dataset.select_dtypes(exclude='number').describe().transpose()
# Out:
#       count unique  top freq
# month   513     12  aug  182
# day     513      7  sun   94

# %% [markdown]
# ### Univariate Analysis

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

skewn = skew(dataset.area, axis=0, bias=True)
kurto = kurtosis(dataset.area, axis=0, bias=True)

print('Skewness: '+str(round(skewn,3)))
print('Kurtosis: '+str(round(kurto,3)))
# Out:
# Skewness: 12.765
# Kurtosis: 190.849

# %%
# plot distribusi area
sns.set(rc={'figure.figsize':(15,7)})
sns.kdeplot(data=dataset, x="area",fill=True)
plt.show()

# %% [markdown]
# Dataset area sangat condong (skew) positif dan memiliki kurtosis yang sangat besar, dari plot distribusi menunjukan bahwa **sebagian besar area kebakaran hutan kurang dari 100 hektar lahan.**

# %%
dataset['area_log'] = dataset.area.apply(lambda x: math.log(x+1))

# %%
# plot distribusi area
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
sns.kdeplot(data=dataset, x="area",fill=True)
plt.title('Distribusi base data')

plt.subplot(1,2,2)
sns.kdeplot(data=dataset, x="area_log",fill=True)
plt.title('Distribusi data ditransformasikan terhadap ln(x+1)')
plt.show()

# %%
# plot univariate barplot
num_cols = dataset.select_dtypes(include='number').columns.to_list()
plt.figure(figsize=(18, 10))
for index in range(0, len(num_cols)):
    plt.subplot(3, 4, index+1)
    sns.histplot(dataset[num_cols[index]], color='steelblue', kde=True)
    plt.xlabel(num_cols[index], fontsize='16', labelpad=10)
    plt.tight_layout()

plt.show();

# %%
month_order = ['dec', 'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov']
day_order = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']

# %%
fig = plt.figure(figsize=(18, 12), facecolor='white')
ax = fig.add_subplot(2, 2, 1)
ax = sns.countplot(x='month', data=dataset,order = month_order)
season = {'Winter':'b','Spring':'g','Summer':'darkorange', 'Fall':'r'}
for i in range(4):
    x1 = (i*3)-0.5
    x2 = (i*3)+2.5
    ax.axvspan(x1,x2, color=list(season.values())[i], alpha=0.15,zorder=0)
    ax.text(x1-0.5+((x2-x1)/2), 190,list(season.keys())[i], fontsize=12)
ax.set(ylim=(0, 200))
ax.set_title('total area pada setiap bulan',fontsize=14)

ax = fig.add_subplot(2, 2, 2)
ax = sns.countplot(x='month', data = dataset, color='lightsteelblue', order = dataset['month'].value_counts().index)
ax.set(ylim=(0, 200))
ax.set_title('total area pada setiap bulan diurutkan dari area yang terbesar',fontsize=14)

ax = fig.add_subplot(2, 2, 3)
ax = sns.countplot(x='day', data=dataset,order = day_order)
ax.set_title('Barplot area pada setiap hari',fontsize=14)

ax = fig.add_subplot(2, 2, 4)
ax = sns.countplot(x='day', data=dataset, color='lightsteelblue', order = dataset['day'].value_counts().index)
ax.set_title('total area pada setiap hari diurutkan dari area yang terbesar',fontsize=14)

plt.show()

# %% [markdown]
# dari barplot data ditunjukan area kebakaran terbanyak ditunjukan pada **bulan agustus** yang kemudian disusul bulan september, kejadian tersebut terjadi pada musim panas menuju kemarau. Namun data kebakaran tidak tersebar merata untuk setiap bulannya. Untuk kasus hari, dimulai hari jumat menunjukan kasus kebakaran mulai naik hingga pada puncaknya pada **hari minggu**, yang kemudian turun kembali di hari senin atau hari kerja. bisa dikatakan kebakaran sering terjadi di akhir pekan

# %%
print('Pesebaran data untuk setiap bulan:')
print(dataset.month.value_counts())
# Out:
# Pesebaran data untuk setiap bulan:
# aug    182
# sep    172
# mar     53
# jul     32
# feb     20
# jun     16
# oct     15
# apr      9
# dec      9
# jan      2
# may      2
# nov      1
# Name: month, dtype: int64

# %% [markdown]
# jumlah data bulan sangat tidak seimbang untuk memiliki 12 kateogori, hal ini dapat menyebabkan overfitting. oleh karena itu fitur bulan dapat diubah menjadi fitur kategori yang lebih ringkas seperti fitur musim (season)

# %%
def to_season(month):
    if month in ['dec', 'jan', 'feb']:
        return 'winter'
    elif month in ['mar', 'apr', 'may']:
        return 'spring'
    elif month in ['jun', 'jul', 'aug']:
        return 'summer'
    else:
        return 'fall'

# %%
dataset['season'] = dataset['month'].apply(to_season)

# %%
sns.countplot(x = 'season', data = dataset )
plt.xlabel('Season',fontsize='16')
plt.show()

# %%
# Peta titik koordinasi kebakaran 
montesinho_park = dataset.groupby(['X', 'Y']).agg(
    area_mean = pd.NamedAgg(column='area', aggfunc='mean'),
    count = pd.NamedAgg(column='X', aggfunc='count'),
).reset_index()

fig, ax = plt.subplots(figsize=(15, 12))
plt.gca().invert_yaxis()
ax.axis('off')
img = mpimg.imread('The-map-of-Montesinho-natural-park.png')
ax = ax.imshow(img)

montesinho_park['X'] = montesinho_park['X'].apply(lambda x: x*img.shape[0]/6)
montesinho_park['Y'] = montesinho_park['Y'].apply(lambda x: x*img.shape[1]/15.5)

ax = sns.scatterplot(x='X', y='Y', hue='count', s=montesinho_park['area_mean']*20, data=montesinho_park, palette="viridis")
plt.show()

# %% [markdown]
# rata-rata area kebakaran terbesar berada pada koordinat X,Y **(8,8)** dan sedangkan jumlah kejadian kebakaran terbanyak terletak pada koordinat **(8,6)**

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(18, 10))
for index in range(0, len(num_cols)):
    plt.subplot(3, 4, index+1)
    plt.scatter(dataset[num_cols[index]], dataset['area'], color='steelblue',alpha=0.3)
    plt.ylabel('area', fontsize='16', labelpad=10)
    plt.xlabel(num_cols[index], fontsize='16', labelpad=10)
    plt.tight_layout()

plt.show();

# %% [markdown]
# dari setiap fitur numerik terhadap area tidak menunjukkan adanya hubungan seperti suatu trend atau kluster

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(15,10))

corr = dataset.corr()
mask = np.triu(np.ones_like(corr))

sns.heatmap(corr, mask=mask,  annot=True, cmap='viridis', linewidths=.5)
plt.show();

# %% [markdown]
# korelasi setiap fitur terhadap variabel target 'area' memiliki hubungan yang **tidak kuat** karena setiap fitur hampir memiliki **nilai korelasi mendekati nol**

# %% [markdown]
# ### Outlier

# %%
# barplot numerical feature
plt.figure(figsize=(18, 12))
for index in range(len(num_cols)):
    plt.subplot(2, round(len(num_cols)/2), index+1)
    sns.boxplot(y=dataset[num_cols[index]], color='lightsteelblue', orient='v')
    plt.ylabel(num_cols[index], fontsize='16', labelpad=10)
    plt.tight_layout()

plt.show();

# %%
# jumlah outlier
Q1 = dataset[num_cols].quantile(0.25)
Q3 = dataset[num_cols].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outlier = ((dataset[num_cols] < (lower)) | (dataset[num_cols] > (upper))).sum()
print(outlier)
# Out:
# X            0
# Y           51
# FFMC        53
# DMC         17
# DC          17
# ISI         14
# temp         2
# RH          12
# wind        13
# rain         8
# area        62
# area_log     8
# dtype: int64

# %% [markdown]
# jika dilihat dari segi boxplot, data sangat memiliki banyak outlier. Apabila outlier dihilangkan atau ditangani maka akan merubah informasi asli dari dataset, maka perlu melakukan pendekatan lainnya untuk mendeteksi outlier. dalam projek ini akan menggunakan isolation forest untuk mendeteksi outlier

# %%
from sklearn.ensemble import IsolationForest
isf = IsolationForest(n_estimators = 100, random_state = 42, contamination = 0.02)
preds = isf.fit_predict(dataset[num_cols])
dataset["outliers"] = preds
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %%
print(dataset["outliers"].value_counts())
# Out:
#  1    502
# -1     11
# Name: outliers, dtype: int64

# %% [markdown]
# menggunakan teknik isolation forest didapatkan 11 outlier ditandai dengan nilai -1

# %%
num_cols = ['X','Y','FFMC','DMC','DC','ISI','temp','RH','wind','rain','area']

def highlight_outlier(x):
    c1 = 'background-color: khaki'
    c2 = 'color: mediumblue; font-weight:bold'
    c3 = 'color: firebrick; font-weight:bold'
    c4 = 'background-color: red'
    
    df = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    for i, col in enumerate(num_cols):
        df.loc[(x[col] > upper[i]), col] = c1
        df.loc[(x[col] < lower[i]), col] = c1
        df.loc[((x[col] == max(x[col])) & (~((x[col] > upper[i]) | (x[col] < lower[i]))), col)] = c2
        df.loc[((x[col] == min(x[col])) & (~((x[col] > upper[i]) | (x[col] < lower[i]))), col)] = c3
        df.loc[((x[col] > upper[i]) | (x[col] < lower[i])) & (x[col] == max(x[col])), col] = c2+';'+c1
        df.loc[((x[col] > upper[i]) | (x[col] < lower[i])) & (x[col] == min(x[col])), col] = c3+';'+c1
    df.loc[(x['outliers'] != 1),'outliers'] = c4
    return df

dataset.sort_values("outliers").style.apply(highlight_outlier, axis=None)
# Out:
# <style type="text/css">
# #T_b8f44_row0_col1, #T_b8f44_row0_col12, #T_b8f44_row1_col12, #T_b8f44_row3_col12, #T_b8f44_row4_col4, #T_b8f44_row5_col6, #T_b8f44_row5_col12, #T_b8f44_row7_col4, #T_b8f44_row7_col6, #T_b8f44_row8_col12, #T_b8f44_row10_col12, #T_b8f44_row11_col12, #T_b8f44_row24_col12, #T_b8f44_row26_col9, #T_b8f44_row39_col7, #T_b8f44_row42_col6, #T_b8f44_row44_col12, #T_b8f44_row45_col5, #T_b8f44_row45_col12, #T_b8f44_row49_col5, #T_b8f44_row50_col5, #T_b8f44_row54_col12, #T_b8f44_row73_col9, #T_b8f44_row73_col11, #T_b8f44_row75_col4, #T_b8f44_row75_col6, #T_b8f44_row75_col12, #T_b8f44_row76_col6, #T_b8f44_row77_col4, #T_b8f44_row77_col8, #T_b8f44_row78_col4, #T_b8f44_row78_col10, #T_b8f44_row78_col12, #T_b8f44_row79_col4, #T_b8f44_row80_col4, #T_b8f44_row80_col10, #T_b8f44_row81_col4, #T_b8f44_row81_col10, #T_b8f44_row81_col12, #T_b8f44_row82_col4, #T_b8f44_row82_col10, #T_b8f44_row83_col4, #T_b8f44_row83_col10, #T_b8f44_row83_col12, #T_b8f44_row84_col4, #T_b8f44_row85_col4, #T_b8f44_row86_col4, #T_b8f44_row86_col10, #T_b8f44_row93_col7, #T_b8f44_row100_col12, #T_b8f44_row102_col12, #T_b8f44_row103_col12, #T_b8f44_row118_col4, #T_b8f44_row118_col9, #T_b8f44_row122_col4, #T_b8f44_row122_col9, #T_b8f44_row129_col5, #T_b8f44_row130_col6, #T_b8f44_row131_col12, #T_b8f44_row134_col12, #T_b8f44_row138_col7, #T_b8f44_row140_col12, #T_b8f44_row142_col12, #T_b8f44_row143_col6, #T_b8f44_row147_col4, #T_b8f44_row147_col6, #T_b8f44_row148_col4, #T_b8f44_row148_col6, #T_b8f44_row149_col5, #T_b8f44_row152_col5, #T_b8f44_row154_col12, #T_b8f44_row158_col5, #T_b8f44_row161_col12, #T_b8f44_row162_col7, #T_b8f44_row163_col4, #T_b8f44_row164_col4, #T_b8f44_row164_col12, #T_b8f44_row165_col4, #T_b8f44_row166_col4, #T_b8f44_row168_col11, #T_b8f44_row171_col10, #T_b8f44_row173_col7, #T_b8f44_row173_col12, #T_b8f44_row174_col7, #T_b8f44_row175_col11, #T_b8f44_row177_col11, #T_b8f44_row178_col12, #T_b8f44_row183_col12, #T_b8f44_row188_col12, #T_b8f44_row191_col11, #T_b8f44_row192_col9, #T_b8f44_row193_col7, #T_b8f44_row198_col4, #T_b8f44_row199_col4, #T_b8f44_row201_col5, #T_b8f44_row202_col4, #T_b8f44_row214_col4, #T_b8f44_row214_col12, #T_b8f44_row215_col4, #T_b8f44_row216_col6, #T_b8f44_row217_col5, #T_b8f44_row217_col12, #T_b8f44_row218_col12, #T_b8f44_row219_col4, #T_b8f44_row221_col12, #T_b8f44_row225_col6, #T_b8f44_row227_col5, #T_b8f44_row228_col6, #T_b8f44_row231_col5, #T_b8f44_row235_col5, #T_b8f44_row238_col5, #T_b8f44_row245_col5, #T_b8f44_row253_col5, #T_b8f44_row254_col7, #T_b8f44_row255_col5, #T_b8f44_row256_col9, #T_b8f44_row277_col4, #T_b8f44_row277_col6, #T_b8f44_row290_col4, #T_b8f44_row290_col6, #T_b8f44_row294_col4, #T_b8f44_row304_col4, #T_b8f44_row304_col6, #T_b8f44_row307_col4, #T_b8f44_row312_col4, #T_b8f44_row313_col4, #T_b8f44_row313_col6, #T_b8f44_row318_col9, #T_b8f44_row327_col7, #T_b8f44_row334_col4, #T_b8f44_row339_col4, #T_b8f44_row340_col7, #T_b8f44_row344_col9, #T_b8f44_row347_col9, #T_b8f44_row348_col9, #T_b8f44_row348_col11, #T_b8f44_row358_col4, #T_b8f44_row375_col4, #T_b8f44_row386_col4, #T_b8f44_row387_col12, #T_b8f44_row388_col12, #T_b8f44_row389_col12, #T_b8f44_row390_col12, #T_b8f44_row391_col12, #T_b8f44_row392_col12, #T_b8f44_row393_col12, #T_b8f44_row394_col12, #T_b8f44_row395_col12, #T_b8f44_row396_col12, #T_b8f44_row397_col12, #T_b8f44_row398_col7, #T_b8f44_row398_col9, #T_b8f44_row398_col12, #T_b8f44_row399_col12, #T_b8f44_row400_col12, #T_b8f44_row401_col12, #T_b8f44_row402_col12, #T_b8f44_row403_col7, #T_b8f44_row407_col4, #T_b8f44_row410_col4, #T_b8f44_row413_col4, #T_b8f44_row415_col12, #T_b8f44_row417_col12, #T_b8f44_row418_col12, #T_b8f44_row432_col12, #T_b8f44_row434_col11, #T_b8f44_row436_col4, #T_b8f44_row438_col4, #T_b8f44_row439_col12, #T_b8f44_row440_col12, #T_b8f44_row441_col4, #T_b8f44_row441_col12, #T_b8f44_row442_col12, #T_b8f44_row443_col12, #T_b8f44_row444_col12, #T_b8f44_row445_col12, #T_b8f44_row446_col12, #T_b8f44_row462_col4, #T_b8f44_row467_col10, #T_b8f44_row471_col4, #T_b8f44_row474_col7, # ...
#   background-color: khaki;
# }
# #T_b8f44_row0_col11, #T_b8f44_row1_col0, #T_b8f44_row1_col11, #T_b8f44_row3_col11, #T_b8f44_row4_col11, #T_b8f44_row4_col12, #T_b8f44_row5_col11, #T_b8f44_row6_col11, #T_b8f44_row7_col11, #T_b8f44_row8_col11, #T_b8f44_row9_col5, #T_b8f44_row9_col7, #T_b8f44_row9_col11, #T_b8f44_row9_col12, #T_b8f44_row10_col11, #T_b8f44_row11_col0, #T_b8f44_row11_col11, #T_b8f44_row12_col11, #T_b8f44_row13_col11, #T_b8f44_row13_col12, #T_b8f44_row14_col11, #T_b8f44_row15_col11, #T_b8f44_row15_col12, #T_b8f44_row16_col11, #T_b8f44_row17_col11, #T_b8f44_row18_col11, #T_b8f44_row18_col12, #T_b8f44_row19_col11, #T_b8f44_row20_col11, #T_b8f44_row20_col12, #T_b8f44_row21_col11, #T_b8f44_row22_col11, #T_b8f44_row23_col11, #T_b8f44_row24_col11, #T_b8f44_row25_col11, #T_b8f44_row25_col12, #T_b8f44_row26_col11, #T_b8f44_row26_col12, #T_b8f44_row27_col11, #T_b8f44_row27_col12, #T_b8f44_row28_col0, #T_b8f44_row28_col11, #T_b8f44_row29_col11, #T_b8f44_row30_col11, #T_b8f44_row31_col11, #T_b8f44_row32_col11, #T_b8f44_row33_col11, #T_b8f44_row33_col12, #T_b8f44_row34_col11, #T_b8f44_row34_col12, #T_b8f44_row35_col11, #T_b8f44_row35_col12, #T_b8f44_row36_col11, #T_b8f44_row37_col11, #T_b8f44_row38_col11, #T_b8f44_row39_col11, #T_b8f44_row40_col11, #T_b8f44_row41_col11, #T_b8f44_row42_col11, #T_b8f44_row42_col12, #T_b8f44_row43_col11, #T_b8f44_row43_col12, #T_b8f44_row44_col11, #T_b8f44_row45_col11, #T_b8f44_row46_col11, #T_b8f44_row46_col12, #T_b8f44_row47_col11, #T_b8f44_row47_col12, #T_b8f44_row48_col11, #T_b8f44_row48_col12, #T_b8f44_row49_col11, #T_b8f44_row50_col11, #T_b8f44_row50_col12, #T_b8f44_row51_col11, #T_b8f44_row52_col11, #T_b8f44_row52_col12, #T_b8f44_row53_col11, #T_b8f44_row54_col11, #T_b8f44_row55_col11, #T_b8f44_row56_col11, #T_b8f44_row57_col11, #T_b8f44_row58_col11, #T_b8f44_row59_col11, #T_b8f44_row60_col0, #T_b8f44_row60_col11, #T_b8f44_row61_col11, #T_b8f44_row61_col12, #T_b8f44_row62_col11, #T_b8f44_row62_col12, #T_b8f44_row63_col11, #T_b8f44_row64_col11, #T_b8f44_row64_col12, #T_b8f44_row65_col11, #T_b8f44_row66_col11, #T_b8f44_row67_col0, #T_b8f44_row67_col11, #T_b8f44_row67_col12, #T_b8f44_row68_col0, #T_b8f44_row68_col11, #T_b8f44_row69_col11, #T_b8f44_row70_col11, #T_b8f44_row70_col12, #T_b8f44_row71_col11, #T_b8f44_row71_col12, #T_b8f44_row72_col11, #T_b8f44_row72_col12, #T_b8f44_row73_col12, #T_b8f44_row74_col11, #T_b8f44_row74_col12, #T_b8f44_row75_col11, #T_b8f44_row76_col11, #T_b8f44_row77_col11, #T_b8f44_row77_col12, #T_b8f44_row78_col11, #T_b8f44_row79_col11, #T_b8f44_row80_col11, #T_b8f44_row81_col11, #T_b8f44_row82_col11, #T_b8f44_row83_col11, #T_b8f44_row84_col11, #T_b8f44_row85_col11, #T_b8f44_row86_col11, #T_b8f44_row87_col11, #T_b8f44_row88_col11, #T_b8f44_row89_col11, #T_b8f44_row90_col11, #T_b8f44_row91_col11, #T_b8f44_row91_col12, #T_b8f44_row92_col11, #T_b8f44_row92_col12, #T_b8f44_row93_col11, #T_b8f44_row94_col11, #T_b8f44_row95_col11, #T_b8f44_row96_col11, #T_b8f44_row97_col11, #T_b8f44_row97_col12, #T_b8f44_row98_col11, #T_b8f44_row99_col11, #T_b8f44_row100_col11, #T_b8f44_row101_col11, #T_b8f44_row102_col11, #T_b8f44_row103_col11, #T_b8f44_row104_col11, #T_b8f44_row105_col11, #T_b8f44_row105_col12, #T_b8f44_row106_col11, #T_b8f44_row107_col11, #T_b8f44_row107_col12, #T_b8f44_row108_col11, #T_b8f44_row108_col12, #T_b8f44_row109_col11, #T_b8f44_row110_col11, #T_b8f44_row110_col12, #T_b8f44_row111_col11, #T_b8f44_row112_col11, #T_b8f44_row112_col12, #T_b8f44_row113_col11, #T_b8f44_row113_col12, #T_b8f44_row114_col11, #T_b8f44_row114_col12, #T_b8f44_row115_col11, #T_b8f44_row116_col11, #T_b8f44_row117_col0, #T_b8f44_row117_col11, #T_b8f44_row117_col12, #T_b8f44_row118_col11, #T_b8f44_row118_col12, #T_b8f44_row119_col11, #T_b8f44_row119_col12, #T_b8f44_row120_col11, #T_b8f44_row121_col11, #T_b8f44_row121_col12, #T_b8f44_row122_col

# %% [markdown]
# tabel ditunjukan data jika diurutkan berdasarkan outlier isolation forest. cell dengan block kuning merupakan outlier dari setiap kolomnya, angka bewarna merah merupakan nilai minimum dari kolom sedangkan biru merupakan nilai maximum dari kolom. data outlier yang dideteksi oleh isolation forest memang terdapat anomali. contoh pada index 379 menunjuk nilai outlier dan nilai maksimum dari fitur `RH` dan minimum pada `FFMC`, index 499 menunjukan nilai outlier dan nilai maksimum dari fitur `rain`, dan index 238 menunjukan nilai `area` yang sangat besar dibandingkan nilai lainnya. untuk projek ini outlier akan dihapus

# %%
dataset_new = dataset[dataset['outliers'] == 1]
dataset_new = dataset_new.drop(['outliers'], axis=1)
dataset_new.reset_index(inplace=True,drop=True)

# %% [markdown]
# ## Feature Engineering

# %%
dataset_new.head()

# %%
dataset_new = dataset_new.drop(['month'], axis=1)

# %%
dataset_new = pd.get_dummies(dataset_new, prefix=['day', 'season'], drop_first= True)

# %%
dataset_new.head()

# %% [markdown]
# ## Modeling

# %%
import math
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.optimizers import Adadelta
from keras.regularizers import l1
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

# %%
def plot_model(x_train, y_train, x_test, y_test, history, model, key, model_type):
    _, train_eval = model.evaluate(x_train, y_train, verbose=0)
    _, valid_eval = model.evaluate(x_test, y_test, verbose=0)
    
    if model_type == 'regression':
        metric = 'mse'
        val_metric = 'val_mse'
    else:
        metric = 'accuracy'
        val_metric = 'val_accuracy'
    
    plt.plot(history.history[metric])
    plt.plot(history.history[val_metric])
    plt.title(key)
    plt.legend(['Train: '+str(round(train_eval,3)), 'Test: '+str(round(valid_eval,3))])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
def eval_model_regression(y_pred, y_test):
    return {
        'mae': mean_absolute_error(y_test, y_pred),
        'mse': mean_squared_error(y_test, y_pred, squared=True),
        'rmse': mean_squared_error(y_test, y_pred, squared=False)
    }

# %%
from sklearn.metrics import recall_score, precision_score, roc_auc_score, accuracy_score
def eval_model_classification(y_pred, y_test):
    y_pred = (y_pred>0.5)
    return {
        'auc': roc_auc_score(y_test, y_pred),
        'accuracy': accuracy_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred)
    }

# %%
def fit_model(x_train, y_train, x_test, y_test, epoch=100, batch_size=[280], optimizer=[RMSprop()], model_type='regression'):
    history_all = {}
    model_all = {}
    eval_model = {} 
    input_dim = x_train.shape[1]
    
    xaxes = len(optimizer)
    yaxes = len(batch_size)
    if yaxes > xaxes:
        yaxes, xaxes = xaxes, yaxes
    
    i = 1
    
    for batch in batch_size:
        for opt in optimizer:
            # name untuk dict keys
            name_opt = opt.get_config()['name']
            key = f'{name_opt} - Batch: {batch}'

            # model building
            model = Sequential()
            
            if model_type == 'regression':
                model.add(Dense(32, input_dim=input_dim,activation='relu',))
                model.add(Dense(32,activation='relu'))
                model.add(Dense(32,activation='relu'))
                model.add(Dense(32,activation='relu'))
                model.add(Dropout(0.5))
                model.add(Dense(1))
                
                model.compile(optimizer=opt, loss='mse', metrics=['mse'])
                
            elif model_type == 'classification':
                n = y_train.shape[1]
                model.add(Dense(input_dim+10, input_dim=input_dim,activation='relu'))
                model.add(Dense(16,activation='relu'))
                model.add(Dense(n,activation='sigmoid'))
                
                if n > 1:
                    loss = 'sparse_categorical_crossentropy'
                else:
                    loss = 'binary_crossentropy'
                    
                model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
                
            es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=100)
            
            # model fitting
            history = model.fit(x_train, y_train, 
                                validation_data = (x_test, y_test), 
                                epochs = epoch, 
                                batch_size = batch,
                                callbacks=[es], 
                                verbose = 0)
            
            # model evaluasi
            if model_type == 'regression':
                eval_model[key] = eval_model_regression(model.predict(x_test), y_test)
            elif model_type == 'classification':
                eval_model[key] = eval_model_classification(model.predict(x_test), y_test)
            
            # plot mse model
            if xaxes != 1 or yaxes != 1 :
                plt.subplot(xaxes,yaxes,i)
            plot_model(x_train, y_train,
                       x_test, y_test,
                       history,model,key,model_type)
            i += 1
            
            history_all[key] = history
            model_all[key] = model

    return history_all, model_all, eval_model

# %% [markdown]
# ## Regresi

# %%
x_r = dataset_new.drop(['area','area_log'], axis = 1)
y_r = dataset_new[['area']]

# %% [markdown]
# ### Base Data

# %%
x_train_r, x_test_r, y_train_r, y_test_r  = train_test_split(x_r, y_r, test_size = 0.2, random_state = 42)

# %%
print(x_train_r.shape,y_train_r.shape)
print(x_test_r.shape,y_test_r.shape)
# Out:
# (351, 19) (351, 1)
# (151, 19) (151, 1)

# %%
history, model, eval_model = fit_model(x_train_r, y_train_r, x_test_r, y_test_r)

# %%
pd.DataFrame(eval_model).transpose()
# Out:
#                            mae         mse       rmse
# RMSprop - Batch: 280  10.01275  213.829539  14.622911

# %% [markdown]
# #### Eksperimen Batch dan Optimizer

# %%
plt.figure(figsize=[20,20])
histories, models, eval_models = fit_model(x_train_r, y_train_r, x_test_r, y_test_r,
                                          batch_size=[1,130,260,len(x_train_r)], 
                                          optimizer=[RMSprop(),Adam(), Adagrad()])

# %%
pd.DataFrame(eval_models).transpose().sort_values('mae').style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_b25db_row0_col0, #T_b25db_row3_col1, #T_b25db_row3_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b25db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b25db_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_b25db_level0_col1" class="col_heading level0 col1" >mse</th>
#       <th id="T_b25db_level0_col2" class="col_heading level0 col2" >rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b25db_level0_row0" class="row_heading level0 row0" >RMSprop - Batch: 1</th>
#       <td id="T_b25db_row0_col0" class="data row0 col0" >6.683323</td>
#       <td id="T_b25db_row0_col1" class="data row0 col1" >200.556292</td>
#       <td id="T_b25db_row0_col2" class="data row0 col2" >14.161790</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row1" class="row_heading level0 row1" >Adam - Batch: 1</th>
#       <td id="T_b25db_row1_col0" class="data row1 col0" >8.218547</td>
#       <td id="T_b25db_row1_col1" class="data row1 col1" >200.044909</td>
#       <td id="T_b25db_row1_col2" class="data row1 col2" >14.143723</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row2" class="row_heading level0 row2" >RMSprop - Batch: 351</th>
#       <td id="T_b25db_row2_col0" class="data row2 col0" >8.351486</td>
#       <td id="T_b25db_row2_col1" class="data row2 col1" >198.904475</td>
#       <td id="T_b25db_row2_col2" class="data row2 col2" >14.103350</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row3" class="row_heading level0 row3" >Adagrad - Batch: 351</th>
#       <td id="T_b25db_row3_col0" class="data row3 col0" >8.379262</td>
#       <td id="T_b25db_row3_col1" class="data row3 col1" >198.126576</td>
#       <td id="T_b25db_row3_col2" class="data row3 col2" >14.075744</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row4" class="row_heading level0 row4" >RMSprop - Batch: 160</th>
#       <td id="T_b25db_row4_col0" class="data row4 col0" >8.455446</td>
#       <td id="T_b25db_row4_col1" class="data row4 col1" >205.862060</td>
#       <td id="T_b25db_row4_col2" class="data row4 col2" >14.347894</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row5" class="row_heading level0 row5" >Adagrad - Batch: 1</th>
#       <td id="T_b25db_row5_col0" class="data row5 col0" >8.561228</td>
#       <td id="T_b25db_row5_col1" class="data row5 col1" >200.514885</td>
#       <td id="T_b25db_row5_col2" class="data row5 col2" >14.160328</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row6" class="row_heading level0 row6" >Adagrad - Batch: 160</th>
#       <td id="T_b25db_row6_col0" class="data row6 col0" >8.741906</td>
#       <td id="T_b25db_row6_col1" class="data row6 col1" >201.897943</td>
#       <td id="T_b25db_row6_col2" class="data row6 col2" >14.209080</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row7" class="row_heading level0 row7" >Adam - Batch: 351</th>
#       <td id="T_b25db_row7_col0" class="data row7 col0" >8.751662</td>
#       <td id="T_b25db_row7_col1" class="data row7 col1" >203.169713</td>
#       <td id="T_b25db_row7_col2" class="data row7 col2" >14.253761</td>
#     </tr>
#     <tr>
#       <th id="T_b25db_level0_row8" class="row_heading level0 row8" >Adam - Batch: 160</th>
#       <td id="T_b25db_row8_col0" class="data row8 col0" >9.139147</td>
#       <td id="T_b25db_row8_col1" class="data row8 col1" >207.117396</td>
#       <td id="T_b25db_row8_col2" class="data row8 col2" >14.391574</td>
#     </tr>
#   </tbody>
# </table>

# %%
y_pred_r = models['RMSprop - Batch: 1'].predict(x_test_r)

# %% [markdown]
# ### Transformed Data (ln(x+1))

# %%
y_rlog = dataset_new[['area_log']]

# %%
x_train_rlog, x_test_rlog, y_train_rlog, y_test_rlog = train_test_split(x_r, y_log, test_size = 0.2, random_state = 42)

# %%
history_log, model_log, eval_model_log = fit_model(x_train_rlog, y_train_rlog, x_test_rlog, y_test_rlog)

# %%
pd.DataFrame(eval_model_log).transpose()
# Out:
#                            mae       mse      rmse
# RMSprop - Batch: 280  1.018744  1.473234  1.213769

# %% [markdown]
# #### Eksperimen Batch dan Optimizer

# %%
plt.figure(figsize=[20,20])
histories_log, models_log, eval_models_log = fit_model(x_train_rlog, y_train_rlog, x_test_rlog, y_test_rlog,
                                          batch_size=[1,130,260,len(x_train_r)], 
                                          optimizer=[RMSprop(),Adam(), Adagrad()])

# %%
pd.DataFrame(eval_models_log).transpose().sort_values('mae').style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_9f1a7_row0_col0, #T_9f1a7_row0_col1, #T_9f1a7_row0_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9f1a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f1a7_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_9f1a7_level0_col1" class="col_heading level0 col1" >mse</th>
#       <th id="T_9f1a7_level0_col2" class="col_heading level0 col2" >rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f1a7_level0_row0" class="row_heading level0 row0" >RMSprop - Batch: 160</th>
#       <td id="T_9f1a7_row0_col0" class="data row0 col0" >1.006944</td>
#       <td id="T_9f1a7_row0_col1" class="data row0 col1" >1.505018</td>
#       <td id="T_9f1a7_row0_col2" class="data row0 col2" >1.226792</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row1" class="row_heading level0 row1" >RMSprop - Batch: 351</th>
#       <td id="T_9f1a7_row1_col0" class="data row1 col0" >1.036377</td>
#       <td id="T_9f1a7_row1_col1" class="data row1 col1" >1.527321</td>
#       <td id="T_9f1a7_row1_col2" class="data row1 col2" >1.235848</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row2" class="row_heading level0 row2" >Adam - Batch: 160</th>
#       <td id="T_9f1a7_row2_col0" class="data row2 col0" >1.049709</td>
#       <td id="T_9f1a7_row2_col1" class="data row2 col1" >1.606875</td>
#       <td id="T_9f1a7_row2_col2" class="data row2 col2" >1.267626</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row3" class="row_heading level0 row3" >Adam - Batch: 351</th>
#       <td id="T_9f1a7_row3_col0" class="data row3 col0" >1.056289</td>
#       <td id="T_9f1a7_row3_col1" class="data row3 col1" >1.552185</td>
#       <td id="T_9f1a7_row3_col2" class="data row3 col2" >1.245867</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row4" class="row_heading level0 row4" >RMSprop - Batch: 1</th>
#       <td id="T_9f1a7_row4_col0" class="data row4 col0" >1.056755</td>
#       <td id="T_9f1a7_row4_col1" class="data row4 col1" >1.531682</td>
#       <td id="T_9f1a7_row4_col2" class="data row4 col2" >1.237611</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row5" class="row_heading level0 row5" >Adam - Batch: 1</th>
#       <td id="T_9f1a7_row5_col0" class="data row5 col0" >1.095138</td>
#       <td id="T_9f1a7_row5_col1" class="data row5 col1" >1.546869</td>
#       <td id="T_9f1a7_row5_col2" class="data row5 col2" >1.243732</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row6" class="row_heading level0 row6" >Adagrad - Batch: 1</th>
#       <td id="T_9f1a7_row6_col0" class="data row6 col0" >1.105346</td>
#       <td id="T_9f1a7_row6_col1" class="data row6 col1" >1.746564</td>
#       <td id="T_9f1a7_row6_col2" class="data row6 col2" >1.321576</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row7" class="row_heading level0 row7" >Adagrad - Batch: 160</th>
#       <td id="T_9f1a7_row7_col0" class="data row7 col0" >1.184299</td>
#       <td id="T_9f1a7_row7_col1" class="data row7 col1" >2.209855</td>
#       <td id="T_9f1a7_row7_col2" class="data row7 col2" >1.486558</td>
#     </tr>
#     <tr>
#       <th id="T_9f1a7_level0_row8" class="row_heading level0 row8" >Adagrad - Batch: 351</th>
#       <td id="T_9f1a7_row8_col0" class="data row8 col0" >3.738946</td>
#       <td id="T_9f1a7_row8_col1" class="data row8 col1" >20.971568</td>
#       <td id="T_9f1a7_row8_col2" class="data row8 col2" >4.579472</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval_models_exp = {}
for m in models_log:
    y_pred_rlog = models_log[m].predict(x_test_rlog)
    exponen = lambda x: math.exp(x)-1
    y_pred_r = np.array([exponen(xi) for xi in y_pred_rlog])
    eval_models_exp[m] = eval_model_regression(y_test_rlog,y_pred_r)

# %%
pd.DataFrame(eval_models_exp).transpose().sort_values('mae').style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
#                            mae         mse       rmse
# RMSprop - Batch: 351  5.948379  213.877282  14.624544

# %%
y_pred_rlog = models_log['Adam - Batch: 130'].predict(x_test_rlog)
exponen = lambda x: math.exp(x)-1
y_pred_trans = np.array([exponen(xi) for xi in y_pred_rlog])

# %%
plt.figure(figsize=(15,7))
ax = sns.kdeplot(y_test_r.area, color="r",legend=True)
ax = sns.kdeplot(y_pred_r.flatten(), color="b",legend=True)
ax = sns.kdeplot(y_pred_trans.flatten(), color="g",legend=True)
plt.legend(['Test','Prediksi (base)','Prediksi (ln(x+1))'])
plt.title('Distribusi Area Prediksi')
plt.show()
